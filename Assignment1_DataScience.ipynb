# %% [markdown]
# <a href="https://colab.research.google.com/github/nadalinemortaoui/gitdagoat/blob/main/Assignment1_DataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)

print('Bibliotheken geladen.')
# Out:
# Bibliotheken geladen.

# %%
df = pd.read_csv('/content/Datentabellen/student_performance.csv')

# %%
df.head(5)
display(df.head())

df.shape
print(df.shape)


df.columns
print(df.columns)
# Out:
#    gender  math_score  reading_score  writing_score study time  absences
# 0  female        63.0           84.0           73.0     medium       5.0
# 1    male        65.0           77.0           63.0        low       2.0
# 2    male        64.0           67.0           81.0        low       4.0
# 3    male        51.0           78.0           68.0        low       4.0
# 4  female        75.0           66.0           63.0        low       8.0
# (91, 6)
# Index(['gender', 'math_score', 'reading_score', 'writing_score', 'study time',
#        'absences'],
#       dtype='object')

# %%
df.isnull().sum()
display(df.isnull().sum())

df = df.dropna()
display(df)

df = df.rename(columns={'study time': 'study_time'}
# Out:
#   File "/tmp/ipython-input-780844118.py", line 8
#
#     ^
# SyntaxError: incomplete input
